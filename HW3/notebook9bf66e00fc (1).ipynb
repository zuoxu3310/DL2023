# %% [markdown]
# # Deep learning for computer vision
#
#
# This notebook will teach you to build and train convolutional networks for image recognition. Brace yourselves.

# %% [markdown]
# # CIFAR dataset
# This week, we shall focus on the image recognition problem on cifar10 dataset
# * 60k images of shape 3x32x32
# * 10 different classes: planes, dogs, cats, trucks, etc.
#
# <img src="cifar10.jpg" style="width:80%">

# %%
# when running in colab, un-comment this
# !wget https://raw.githubusercontent.com/yandexdataschool/Practical_DL/fall19/week03_convnets/cifar.py
# Out:
# --2023-10-08 10:28:20--  https://raw.githubusercontent.com/yandexdataschool/Practical_DL/fall19/week03_convnets/cifar.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2396 (2.3K) [text/plain]
# Saving to: ‘cifar.py’
#
# cifar.py            100%[===================>]   2.34K  --.-KB/s    in 0s
#
# 2023-10-08 10:28:20 (26.5 MB/s) - ‘cifar.py’ saved [2396/2396]

# %%
import numpy as np
from cifar import load_cifar10
X_train, y_train, X_val, y_val, X_test, y_test = load_cifar10("cifar_data")

class_names = np.array(['airplane', 'automobile', 'bird', 'cat', 'deer',
                        'dog', 'frog', 'horse', 'ship', 'truck'])

print(X_train.shape,y_train.shape)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Dataset not found. Downloading...
# (40000, 3, 32, 32) (40000,)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=[12,10])
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.xlabel(class_names[y_train[i]])
    plt.imshow(np.transpose(X_train[i],[1,2,0]))

# %% [markdown]
# # Building a network
#
# Simple neural networks with layers applied on top of one another can be implemented as `torch.nn.Sequential` - just add a list of pre-built modules and let it train.

# %%
import torch, torch.nn as nn
import torch.nn.functional as F

# a special module that converts [batch, channel, w, h] to [batch, units]
class Flatten(nn.Module):
    def forward(self, input):
        return input.view(input.size(0), -1)

# %% [markdown]
# Let's start with a dense network for our baseline:

# %%
model = nn.Sequential()

# reshape from "images" to flat vectors
model.add_module('flatten', Flatten())

# dense "head"
model.add_module('dense1', nn.Linear(3 * 32 * 32, 64))
model.add_module('dense1_relu', nn.ReLU())
model.add_module('dense2_logits', nn.Linear(64, 10)) # logits for 10 classes

# %%
device = 'cuda'

# %%
model.to(device)
# Out:
# Sequential(
#   (flatten): Flatten()
#   (dense1): Linear(in_features=3072, out_features=64, bias=True)
#   (dense1_relu): ReLU()
#   (dense2_logits): Linear(in_features=64, out_features=10, bias=True)
# )

# %% [markdown]
# As in our basic tutorial, we train our model with negative log-likelihood aka crossentropy.

# %%
def compute_loss(X_batch, y_batch):
    X_batch = torch.as_tensor(X_batch, dtype=torch.float32).to(device)
    y_batch = torch.as_tensor(y_batch, dtype=torch.int64).to(device)
    logits = model(X_batch)
    return F.cross_entropy(logits, y_batch).mean()

# %%
# example
compute_loss(X_train[:5], y_train[:5])
# Out:
# tensor(2.3008, device='cuda:0', grad_fn=<MeanBackward0>)

# %% [markdown]
# ### Training on minibatches
# * We got 40k images, that's way too many for a full-batch SGD. Let's train on minibatches instead
# * Below is a function that splits the training sample into minibatches

# %%
# An auxilary function that returns mini-batches for neural network training
def iterate_minibatches(X, y, batchsize):
    indices = np.random.permutation(np.arange(len(X)))
    for start in range(0, len(indices), batchsize):
        ix = indices[start: start + batchsize]
        yield X[ix], y[ix]

# %%
opt = torch.optim.SGD(model.parameters(), lr=0.01)

train_loss = []
val_accuracy = []

# %%
import time
num_epochs = 100 # total amount of full passes over training data
batch_size = 50  # number of samples processed in one SGD iteration

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.cpu().data.numpy())

    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in iterate_minibatches(X_val, y_val, batch_size):
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
        y_pred = logits.max(1)[1].cpu().data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))


    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 100 took 1.113s
#   training loss (in-iteration): 	2.025912
#   validation accuracy: 			32.77 %
# Epoch 2 of 100 took 1.069s
#   training loss (in-iteration): 	1.859758
#   validation accuracy: 			37.22 %
# Epoch 3 of 100 took 1.067s
#   training loss (in-iteration): 	1.791674
#   validation accuracy: 			36.61 %
# Epoch 4 of 100 took 1.060s
#   training loss (in-iteration): 	1.741152
#   validation accuracy: 			38.79 %
# Epoch 5 of 100 took 1.059s
#   training loss (in-iteration): 	1.698509
#   validation accuracy: 			41.50 %
# Epoch 6 of 100 took 1.126s
#   training loss (in-iteration): 	1.660633
#   validation accuracy: 			41.24 %
# Epoch 7 of 100 took 1.100s
#   training loss (in-iteration): 	1.633368
#   validation accuracy: 			42.68 %
# Epoch 8 of 100 took 1.058s
#   training loss (in-iteration): 	1.607895
#   validation accuracy: 			43.02 %
# Epoch 9 of 100 took 1.056s
#   training loss (in-iteration): 	1.586208
#   validation accuracy: 			44.17 %
# Epoch 10 of 100 took 1.052s
#   training loss (in-iteration): 	1.568499
#   validation accuracy: 			44.70 %
# Epoch 11 of 100 took 1.093s
#   training loss (in-iteration): 	1.551426
#   validation accuracy: 			45.11 %
# Epoch 12 of 100 took 1.073s
#   training loss (in-iteration): 	1.535741
#   validation accuracy: 			45.58 %
# Epoch 13 of 100 took 1.077s
#   training loss (in-iteration): 	1.521253
#   validation accuracy: 			45.00 %
# Epoch 14 of 100 took 1.070s
#   training loss (in-iteration): 	1.508577
#   validation accuracy: 			46.49 %
# Epoch 15 of 100 took 1.065s
#   training loss (in-iteration): 	1.497073
#   validation accuracy: 			45.46 %
# Epoch 16 of 100 took 1.061s
#   training loss (in-iteration): 	1.483164
#   validation accuracy: 			47.38 %
# Epoch 17 of 100 took 1.127s
#   training loss (in-iteration): 	1.474187
#   validation accuracy: 			46.94 %
# Epoch 18 of 100 took 1.066s
#   training loss (in-iteration): 	1.462991
#   validation accuracy: 			46.88 %
# Epoch 19 of 100 took 1.072s
#   training loss (in-iteration): 	1.454543
#   validation accuracy: 			47.61 %
# Epoch 20 of 100 took 1.066s
#   training loss (in-iteration): 	1.443844
#   validation accuracy: 			44.56 %
# Epoch 21 of 100 took 1.062s
#   training loss (in-iteration): 	1.432778
#   validation accuracy: 			48.33 %
# Epoch 22 of 100 took 1.061s
#   training loss (in-iteration): 	1.426113
#   validation accuracy: 			46.50 %
# Epoch 23 of 100 took 1.044s
#   training loss (in-iteration): 	1.415719
#   validation accuracy: 			48.41 %
# Epoch 24 of 100 took 1.060s
#   training loss (in-iteration): 	1.407476
#   validation accuracy: 			48.51 %
# Epoch 25 of 100 took 1.159s
#   training loss (in-iteration): 	1.399393
#   validation accuracy: 			48.48 %
# Epoch 26 of 100 took 1.250s
#   training loss (in-iteration): 	1.392183
#   validation accuracy: 			48.29 %
# Epoch 27 of 100 took 1.073s
#   training loss (in-iteration): 	1.386405
#   validation accuracy: 			48.50 %
# Epoch 28 of 100 took 1.094s
#   training loss (in-iteration): 	1.378914
#   validation accuracy: 			48.84 %
# Epoch 29 of 100 took 1.073s
#   training loss (in-iteration): 	1.370018
#   validation accuracy: 			48.08 %
# Epoch 30 of 100 took 1.067s
#   training loss (in-iteration): 	1.367281
#   validation accuracy: 			48.94 %
# Epoch 31 of 100 took 1.066s
#   training loss (in-iteration): 	1.359144
#   validation accuracy: 			49.57 %
# Epoch 32 of 100 took 1.060s
#   training loss (in-iteration): 	1.355815
#   validation accuracy: 			47.50 %
# Epoch 33 of 100 took 1.080s
#   training loss (in-iteration): 	1.347707
#   validation accuracy: 			49.19 %
# Epoch 34 of 100 took 1.080s
#   training loss (in-iteration): 	1.341317
#   validation accuracy: 			48.09 %
# Epoch 35 of 100 took 1.112s
#   training loss (in-iteration): 	1.336694
#   validation accuracy: 			49.34 %
# Epoch 36 of 100 took 1.068s
#   training loss (in-iteration): 	1.332138
#   validation accuracy: 			49.49 %
# Epoch 37 of 100 took 1.065s
#   training loss (in-iteration): 	1.322252
#   validation accuracy: 			49.28 %
# Epoch 38 of 100 took 1.070s
#   training loss (in-iteration): 	1.320626
#   validation accuracy: 			49.44 %
# Epoch 39 of 100 took 1.066s
#   training loss (in-iteration): 	1.315955
#   validation accuracy: 			49.91 %
# Epoch 40 of 100 took 1.069s
#   training loss (in-iteration): 	1.308575
#   validation accuracy: 			49.99 %
# Epoch 41 of 100 took 1.065s
#   training loss (in-iteration): 	1.307178
#   validation accuracy: 			50.39 %
# Epoch 42 of 100 took 1.044s
#   training loss (in-iteration): 	1.301868
#   validation accuracy: 			49.18 %
# Epoch 43 of 100 took 1.062s
#   training loss (in-iteration): 	1.297456
#   validation accuracy: 			50.09 %
# Epoch 44 of 100 took 1.077s
#   training loss (in-iteration): 	1.293640
#   validation accuracy: 			48.79 %
# Epoch 45 of 100 took 1.097s
#   training loss (in-iteration): 	1.287436
#   validation accuracy: 			49.71 %
# Epoch 46 of 100 took 1.065s
#   training loss (in-iteration): 	1.285003
#   validation accuracy: 			49.51 %
# Epoch 47 of 100 took 1.063s
#   training loss (in-iteration): 	1.279178
#   validation accuracy: 			50.26 %
# Epoch 48 of 100 took 1.062s
#   training loss (in-iteration): 	1.275067
#   validation accuracy: 			49.48 %
# Epoch 49 of 100 took 1.066s
#   training loss (in-iteration): 	1.273454
#   validation accuracy: 			50.04 %
# Epoch 50 of 100 took 1.070s
#   training loss (in-iteration): 	1.269052
#   validation accuracy: 			49.55 %
# Epoch 51 of 100 took 1.066s
#   training loss (in-iteration): 	1.264793
#   validation accuracy: 			50.35 %
# Epoch 52 of 100 took 1.059s
#   training loss (in-iteration): 	1.261250
#   validation accuracy: 			49.92 %
# Epoch 53 of 100 took 1.064s
#   training loss (in-iteration): 	1.257195
#   validation accuracy: 			48.00 %
# Epoch 54 of 100 took 1.140s
#   training loss (in-iteration): 	1.254220
#   validation accuracy: 			49.52 %
# Epoch 55 of 100 took 1.245s
#   training loss (in-iteration): 	1.251975
#   validation accuracy: 			50.72 %
# Epoch 56 of 100 took 1.087s
#   training loss (in-iteration): 	1.244274
#   validation accuracy: 			51.09 %
# Epoch 57 of 100 took 1.093s
#   training loss (in-iteration): 	1.242482
#   validation accuracy: 			49.36 %
# Epoch 58 of 100 took 1.075s
#   training loss (in-iteration): 	1.239210
#   validation accuracy: 			49.92 %
# Epoch 59 of 100 took 1.067s
#   training loss (in-iteration): 	1.235491
#   validation accuracy: 			49.35 %
# Epoch 60 of 100 took 1.060s
#   training loss (in-iteration): 	1.231838
#   validation accuracy: 			48.53 %
# Epoch 61 of 100 took 1.058s
#   training loss (in-iteration): 	1.230107
#   validation accuracy: 			49.16 %
# Epoch 62 of 100 took 1.072s
#   training loss (in-iteration): 	1.226040
#   validation accuracy: 			49.42 %
# Epoch 63 of 100 took 1.123s
#   training loss (in-iteration): 	1.222597
#   validation accuracy: 			49.92 %
# Epoch 64 of 100 took 1.087s
#   training loss (in-iteration): 	1.219328
#   validation accuracy: 			50.62 %
# Epoch 65 of 100 took 1.078s
#   training loss (in-iteration): 	1.216212
#   validation accuracy: 			49.29 %
# Epoch 66 of 100 took 1.074s
#   training loss (in-iteration): 	1.211284
#   validation accuracy: 			50.61 %
# Epoch 67 of 100 took 1.078s
#   training loss (in-iteration): 	1.209847
#   validation accuracy: 			50.83 %
# Epoch 68 of 100 took 1.081s
#   training loss (in-iteration): 	1.207336
#   validation accuracy: 			50.05 %
# Epoch 69 of 100 took 1.085s
#   training loss (in-iteration): 	1.203917
#   validation accuracy: 			49.18 %
# Epoch 70 of 100 took 1.077s
#   training loss (in-iteration): 	1.200110
#   validation accuracy: 			48.97 %
# Epoch 71 of 100 took 1.095s
#   training loss (in-iteration): 	1.194445
#   validation accuracy: 			50.12 %
# Epoch 72 of 100 took 1.129s
#   training loss (in-iteration): 	1.194527
#   validation accuracy: 			50.46 %
# Epoch 73 of 100 took 1.072s
#   training loss (in-iteration): 	1.191221
#   validation accuracy: 			49.04 %
# Epoch 74 of 100 took 1.074s
#   training loss (in-iteration): 	1.194031
#   validation accuracy: 			49.78 %
# Epoch 75 of 100 took 1.073s
#   training loss (in-iteration): 	1.186944
#   validation accuracy: 			50.07 %
# Epoch 76 of 100 took 1.094s
#   training loss (in-iteration): 	1.183957
#   validation accuracy: 			50.00 %
# Epoch 77 of 100 took 1.063s
#   training loss (in-iteration): 	1.177527
#   validation accuracy: 			49.75 %
# Epoch 78 of 100 took 1.062s
#   training loss (in-iteration): 	1.175590
#   validation accuracy: 			49.69 %
# Epoch 79 of 100 took 1.069s
#   training loss (in-iteration): 	1.174098
#   validation accuracy: 			49.90 %
# Epoch 80 of 100 took 1.074s
#   training loss (in-iteration): 	1.169105
#   validation accuracy: 			50.66 %
# Epoch 81 of 100 took 1.109s
#   training loss (in-iteration): 	1.165479
#   validation accuracy: 			49.16 %
# Epoch 82 of 100 took 1.064s
#   training loss (in-iteration): 	1.167935
#   validation accuracy: 			50.28 %
# Epoch 83 of 100 took 1.066s
#   training loss (in-iteration): 	1.162129
#   validation accuracy: 			49.97 %
# Epoch 84 of 100 took 1.263s
#   training loss (in-iteration): 	1.159949
#   validation accuracy: 			50.30 %
# Epoch 85 of 100 took 1.097s
#   training loss (in-iteration): 	1.155847
#   validation accuracy: 			49.85 %
# Epoch 86 of 100 took 1.067s
#   training loss (in-iteration): 	1.157090
#   validation accuracy: 			49.94 %
# Epoch 87 of 100 took 1.064s
#   training loss (in-iteration): 	1.149311
#   validation accuracy: 			50.70 %
# Epoch 88 of 100 took 1.073s
#   training loss (in-iteration): 	1.149444
#   validation accuracy: 			49.72 %
# Epoch 89 of 100 took 1.084s
#   training loss (in-iteration): 	1.143453
#   validation accuracy: 			50.48 %
# Epoch 90 of 100 took 1.059s
#   training loss (in-iteration): 	1.145723
#   validation accuracy: 			50.98 %
# Epoch 91 of 100 took 1.106s
#   training loss (in-iteration): 	1.139797
#   validation accuracy: 			50.59 %
# Epoch 92 of 100 took 1.074s
#   training loss (in-iteration): 	1.139714
#   validation accuracy: 			48.78 %
# Epoch 93 of 100 took 1.067s
#   training loss (in-iteration): 	1.137323
#   validation accuracy: 			49.87 %
# Epoch 94 of 100 took 1.068s
#   training loss (in-iteration): 	1.132715
#   validation accuracy: 			49.68 %
# Epoch 95 of 100 took 1.068s
#   training loss (in-iteration): 	1.129563
#   validation accuracy: 			50.18 %
# Epoch 96 of 100 took 1.077s
#   training loss (in-iteration): 	1.133062
#   validation accuracy: 			51.01 %
# Epoch 97 of 100 took 1.063s
#   training loss (in-iteration): 	1.125617
#   validation accuracy: 			49.09 %
# Epoch 98 of 100 took 1.066s
#   training loss (in-iteration): 	1.124905
#   validation accuracy: 			50.57 %
# Epoch 99 of 100 took 1.063s
#   training loss (in-iteration): 	1.123595
#   validation accuracy: 			48.79 %
# Epoch 100 of 100 took 1.107s
#   training loss (in-iteration): 	1.120345
#   validation accuracy: 			50.66 %

# %% [markdown]
# Don't wait for full 100 epochs. You can interrupt training after 5-20 epochs once validation accuracy stops going up.
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ### Final test

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in iterate_minibatches(X_test, y_test, 500):
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
    y_pred = logits.max(1)[1].cpu().data.numpy()
    test_batch_acc.append(np.mean(y_batch == y_pred))

test_accuracy = np.mean(test_batch_acc)

print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		50.52 %
# Achievement unlocked: 60lvl Warlock!

# %% [markdown]
# ## Task I: small convolution net
# ### First step
#
# Let's create a mini-convolutional network with roughly such architecture:
# * Input layer
# * 3x3 convolution with 10 filters and _ReLU_ activation
# * 2x2 pooling (or set previous convolution stride to 3)
# * Flatten
# * Dense layer with 100 neurons and _ReLU_ activation
# * 10% dropout
# * Output dense layer.
#
#
# __Convolutional layers__ in torch are just like all other layers, but with a specific set of parameters:
#
# __`...`__
#
# __`model.add_module('conv1', nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3)) # convolution`__
#
# __`model.add_module('pool1', nn.MaxPool2d(2)) # max pooling 2x2`__
#
# __`...`__
#
#
# Once you're done (and compute_loss no longer raises errors), train it with __Adam__ optimizer with default params (feel free to modify the code above).
#
# If everything is right, you should get at least __50%__ validation accuracy.

# %%
model = nn.Sequential(
    nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3, stride=3),
    nn.ReLU(),
    Flatten(),
    nn.Linear(10 * 10 * 10, 100),
    nn.ReLU(),
    nn.Dropout(0.1),
    nn.Linear(100, 10)
).to(device)

# %%
# example
compute_loss(X_train[:5], y_train[:5])
# Out:
# tensor(2.2771, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
import time
num_epochs = 20 # total amount of full passes over training data
batch_size = 50  # number of samples processed in one SGD iteration

opt = torch.optim.Adam(model.parameters())

train_loss = []
val_accuracy = []

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.cpu().data.numpy())

    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in iterate_minibatches(X_val, y_val, batch_size):
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
        y_pred = logits.max(1)[1].cpu().data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))


    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 20 took 2.590s
#   training loss (in-iteration): 	1.795411
#   validation accuracy: 			44.68 %
# Epoch 2 of 20 took 1.516s
#   training loss (in-iteration): 	1.544332
#   validation accuracy: 			48.20 %
# Epoch 3 of 20 took 1.621s
#   training loss (in-iteration): 	1.448964
#   validation accuracy: 			49.89 %
# Epoch 4 of 20 took 1.542s
#   training loss (in-iteration): 	1.381755
#   validation accuracy: 			51.14 %
# Epoch 5 of 20 took 1.527s
#   training loss (in-iteration): 	1.318965
#   validation accuracy: 			53.13 %
# Epoch 6 of 20 took 1.530s
#   training loss (in-iteration): 	1.263604
#   validation accuracy: 			54.17 %
# Epoch 7 of 20 took 1.570s
#   training loss (in-iteration): 	1.227666
#   validation accuracy: 			54.84 %
# Epoch 8 of 20 took 1.600s
#   training loss (in-iteration): 	1.189638
#   validation accuracy: 			55.37 %
# Epoch 9 of 20 took 1.534s
#   training loss (in-iteration): 	1.157820
#   validation accuracy: 			56.02 %
# Epoch 10 of 20 took 1.848s
#   training loss (in-iteration): 	1.130065
#   validation accuracy: 			55.54 %
# Epoch 11 of 20 took 1.529s
#   training loss (in-iteration): 	1.103306
#   validation accuracy: 			56.49 %
# Epoch 12 of 20 took 1.548s
#   training loss (in-iteration): 	1.081967
#   validation accuracy: 			56.43 %
# Epoch 13 of 20 took 1.567s
#   training loss (in-iteration): 	1.058837
#   validation accuracy: 			57.01 %
# Epoch 14 of 20 took 1.575s
#   training loss (in-iteration): 	1.039467
#   validation accuracy: 			56.08 %
# Epoch 15 of 20 took 1.555s
#   training loss (in-iteration): 	1.016359
#   validation accuracy: 			56.59 %
# Epoch 16 of 20 took 1.534s
#   training loss (in-iteration): 	0.998719
#   validation accuracy: 			57.09 %
# Epoch 17 of 20 took 1.560s
#   training loss (in-iteration): 	0.982041
#   validation accuracy: 			56.42 %
# Epoch 18 of 20 took 1.532s
#   training loss (in-iteration): 	0.958722
#   validation accuracy: 			57.01 %
# Epoch 19 of 20 took 1.537s
#   training loss (in-iteration): 	0.940787
#   validation accuracy: 			56.64 %
# Epoch 20 of 20 took 1.589s
#   training loss (in-iteration): 	0.926122
#   validation accuracy: 			56.53 %

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in iterate_minibatches(X_test, y_test, 500):
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
    y_pred = logits.max(1)[1].cpu().data.numpy()
    test_batch_acc.append(np.mean(y_batch == y_pred))

test_accuracy = np.mean(test_batch_acc)

print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		55.44 %
# Achievement unlocked: 60lvl Warlock!

# %%
model = nn.Sequential(
    nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3),
    nn.ReLU(),
    nn.MaxPool2d(2),
    Flatten(),
    nn.Linear(10 * 15 * 15, 100),
    nn.ReLU(),
    nn.Dropout(0.1),
    nn.Linear(100, 10)
).to(device)

# %%
# example
compute_loss(X_train[:5], y_train[:5])
# Out:
# tensor(2.3288, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
import time
num_epochs = 14 # total amount of full passes over training data
batch_size = 50  # number of samples processed in one SGD iteration

opt = torch.optim.Adam(model.parameters())

train_loss = []
val_accuracy = []

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.cpu().data.numpy())

    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in iterate_minibatches(X_val, y_val, batch_size):
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
        y_pred = logits.max(1)[1].cpu().data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))


    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 14 took 1.584s
#   training loss (in-iteration): 	1.689993
#   validation accuracy: 			49.51 %
# Epoch 2 of 14 took 1.603s
#   training loss (in-iteration): 	1.403951
#   validation accuracy: 			52.87 %
# Epoch 3 of 14 took 1.613s
#   training loss (in-iteration): 	1.315218
#   validation accuracy: 			54.92 %
# Epoch 4 of 14 took 1.589s
#   training loss (in-iteration): 	1.245595
#   validation accuracy: 			57.13 %
# Epoch 5 of 14 took 1.606s
#   training loss (in-iteration): 	1.195173
#   validation accuracy: 			57.73 %
# Epoch 6 of 14 took 1.648s
#   training loss (in-iteration): 	1.146560
#   validation accuracy: 			57.79 %
# Epoch 7 of 14 took 1.586s
#   training loss (in-iteration): 	1.102906
#   validation accuracy: 			58.81 %
# Epoch 8 of 14 took 1.596s
#   training loss (in-iteration): 	1.070992
#   validation accuracy: 			58.92 %
# Epoch 9 of 14 took 1.599s
#   training loss (in-iteration): 	1.042551
#   validation accuracy: 			60.23 %
# Epoch 10 of 14 took 1.844s
#   training loss (in-iteration): 	1.009972
#   validation accuracy: 			60.45 %
# Epoch 11 of 14 took 1.589s
#   training loss (in-iteration): 	0.982457
#   validation accuracy: 			59.54 %
# Epoch 12 of 14 took 1.665s
#   training loss (in-iteration): 	0.955402
#   validation accuracy: 			59.91 %
# Epoch 13 of 14 took 1.586s
#   training loss (in-iteration): 	0.934682
#   validation accuracy: 			60.49 %
# Epoch 14 of 14 took 1.636s
#   training loss (in-iteration): 	0.913744
#   validation accuracy: 			60.10 %

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in iterate_minibatches(X_test, y_test, 500):
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
    y_pred = logits.max(1)[1].cpu().data.numpy()
    test_batch_acc.append(np.mean(y_batch == y_pred))

test_accuracy = np.mean(test_batch_acc)

print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		59.30 %
# Achievement unlocked: 60lvl Warlock!

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# __Hint:__ If you don't want to compute shapes by hand, just plug in any shape (e.g. 1 unit) and run compute_loss. You will see something like this:
#
# __`RuntimeError: size mismatch, m1: [5 x 1960], m2: [1 x 64] at /some/long/path/to/torch/operation`__
#
# See the __1960__ there? That's your actual input shape.
#
# ## Task 2: adding normalization
#
# * Add batch norm (with default params) between convolution and ReLU
#   * nn.BatchNorm*d (1d for dense, 2d for conv)
#   * usually better to put them after linear/conv but before nonlinearity
# * Re-train the network with the same optimizer, it should get at least 60% validation accuracy at peak.

# %%
model = nn.Sequential(
    nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3),
    nn.BatchNorm2d(10),
    nn.ReLU(),
    nn.MaxPool2d(2),
    Flatten(),
    nn.Linear(10 * 15 * 15, 100),
    nn.BatchNorm1d(100),
    nn.ReLU(),
    nn.Dropout(0.1),
    nn.Linear(100, 10)
).to(device)

# %%
# example
compute_loss(X_train[:5], y_train[:5])
# Out:
# tensor(2.7434, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
import time
num_epochs = 13 # total amount of full passes over training data
batch_size = 50  # number of samples processed in one SGD iteration

opt = torch.optim.Adam(model.parameters())

train_loss = []
val_accuracy = []

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.cpu().data.numpy())

    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in iterate_minibatches(X_val, y_val, batch_size):
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
        y_pred = logits.max(1)[1].cpu().data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))


    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 13 took 1.923s
#   training loss (in-iteration): 	1.380220
#   validation accuracy: 			56.36 %
# Epoch 2 of 13 took 1.925s
#   training loss (in-iteration): 	1.118294
#   validation accuracy: 			58.28 %
# Epoch 3 of 13 took 1.905s
#   training loss (in-iteration): 	1.008739
#   validation accuracy: 			61.03 %
# Epoch 4 of 13 took 1.935s
#   training loss (in-iteration): 	0.922978
#   validation accuracy: 			61.46 %
# Epoch 5 of 13 took 1.963s
#   training loss (in-iteration): 	0.849148
#   validation accuracy: 			61.90 %
# Epoch 6 of 13 took 2.135s
#   training loss (in-iteration): 	0.783882
#   validation accuracy: 			63.07 %
# Epoch 7 of 13 took 1.898s
#   training loss (in-iteration): 	0.733696
#   validation accuracy: 			60.87 %
# Epoch 8 of 13 took 1.879s
#   training loss (in-iteration): 	0.673359
#   validation accuracy: 			63.13 %
# Epoch 9 of 13 took 1.934s
#   training loss (in-iteration): 	0.634881
#   validation accuracy: 			63.36 %
# Epoch 10 of 13 took 2.044s
#   training loss (in-iteration): 	0.591213
#   validation accuracy: 			59.64 %
# Epoch 11 of 13 took 2.056s
#   training loss (in-iteration): 	0.555218
#   validation accuracy: 			58.30 %
# Epoch 12 of 13 took 1.887s
#   training loss (in-iteration): 	0.514210
#   validation accuracy: 			62.33 %
# Epoch 13 of 13 took 1.882s
#   training loss (in-iteration): 	0.486728
#   validation accuracy: 			60.56 %

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in iterate_minibatches(X_test, y_test, 500):
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
    y_pred = logits.max(1)[1].cpu().data.numpy()
    test_batch_acc.append(np.mean(y_batch == y_pred))

test_accuracy = np.mean(test_batch_acc)

print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		60.03 %
# Achievement unlocked: 70lvl Warlock!

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
# ## Task 3: Data Augmentation
#
# There's a powerful torch tool for image preprocessing useful to do data preprocessing and augmentation.
#
# Here's how it works: we define a pipeline that
# * makes random crops of data (augmentation)
# * randomly flips image horizontally (augmentation)
# * then normalizes it (preprocessing)

# %%
from torchvision import transforms
means = np.array((0.4914, 0.4822, 0.4465))
stds = np.array((0.2023, 0.1994, 0.2010))

transform_augment = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation([-30, 30]),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

# %%
from torchvision.datasets import CIFAR10
train_loader = CIFAR10("./cifar_data/", train=True, transform=transform_augment)

train_batch_gen = torch.utils.data.DataLoader(train_loader,
                                              batch_size=32,
                                              shuffle=True,
                                              num_workers=1)

# %%
for (x_batch, y_batch) in train_batch_gen:

    print('X:', type(x_batch), x_batch.shape)
    print('y:', type(y_batch), y_batch.shape)

    for i, img in enumerate(x_batch.numpy()[:8]):
        plt.subplot(2, 4, i+1)
        plt.imshow(img.transpose([1,2,0]) * stds + means )


    raise NotImplementedError("Plese use this code in your training loop")
    # TODO use this in your training loop
# Out:
# X: <class 'torch.Tensor'> torch.Size([32, 3, 32, 32])
# y: <class 'torch.Tensor'> torch.Size([32])
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[27], line 11
#       7     plt.subplot(2, 4, i+1)
#       8     plt.imshow(img.transpose([1,2,0]) * stds + means )
# ---> 11 raise NotImplementedError("Plese use this code in your training loop")
#      12 # TODO use this in your training loop
#
# NotImplementedError: Plese use this code in your training loop

# %% [markdown]
# When testing, we don't need random crops, just normalize with same statistics.

# %%
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

test_loader = CIFAR10(root="./cifar_data/", train=False, transform=transform_test)

test_batch_gen = torch.utils.data.DataLoader(test_loader, batch_size=32, shuffle=False, num_workers=2)

# %%
from torch.utils.data import DataLoader, random_split


full_train_dataset = CIFAR10("./cifar_data/", train=True, transform=transform_augment)

train_size = int(0.9 * len(full_train_dataset))
val_size = len(full_train_dataset) - train_size

train_dataset, val_dataset = random_split(full_train_dataset, [train_size, val_size])

train_batch_gen = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
val_batch_gen = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2)

# %%
import time
num_epochs = 20 # total amount of full passes over training data

opt = torch.optim.Adam(model.parameters())

train_loss = []
val_accuracy = []

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in train_batch_gen:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.cpu().data.numpy())

    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in val_batch_gen:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
        y_pred = logits.max(1)[1].cpu().data.numpy()
        y_batch = y_batch.cpu().numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))


    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 20 took 23.320s
#   training loss (in-iteration): 	1.242360
#   validation accuracy: 			58.92 %
# Epoch 2 of 20 took 23.714s
#   training loss (in-iteration): 	1.237205
#   validation accuracy: 			59.16 %
# Epoch 3 of 20 took 24.188s
#   training loss (in-iteration): 	1.247032
#   validation accuracy: 			59.39 %
# Epoch 4 of 20 took 24.485s
#   training loss (in-iteration): 	1.226609
#   validation accuracy: 			58.05 %
# Epoch 5 of 20 took 23.397s
#   training loss (in-iteration): 	1.231528
#   validation accuracy: 			58.45 %
# Epoch 6 of 20 took 24.391s
#   training loss (in-iteration): 	1.233411
#   validation accuracy: 			59.61 %
# Epoch 7 of 20 took 23.682s
#   training loss (in-iteration): 	1.226580
#   validation accuracy: 			59.58 %
# Epoch 8 of 20 took 24.102s
#   training loss (in-iteration): 	1.226487
#   validation accuracy: 			59.92 %
# Epoch 9 of 20 took 23.141s
#   training loss (in-iteration): 	1.232480
#   validation accuracy: 			59.30 %
# Epoch 10 of 20 took 23.805s
#   training loss (in-iteration): 	1.221266
#   validation accuracy: 			59.38 %
# Epoch 11 of 20 took 24.020s
#   training loss (in-iteration): 	1.219386
#   validation accuracy: 			59.16 %
# Epoch 12 of 20 took 23.729s
#   training loss (in-iteration): 	1.222637
#   validation accuracy: 			60.12 %
# Epoch 13 of 20 took 23.358s
#   training loss (in-iteration): 	1.214398
#   validation accuracy: 			59.56 %
# Epoch 14 of 20 took 23.991s
#   training loss (in-iteration): 	1.212123
#   validation accuracy: 			60.22 %
# Epoch 15 of 20 took 23.910s
#   training loss (in-iteration): 	1.220550
#   validation accuracy: 			60.86 %
# Epoch 16 of 20 took 23.990s
#   training loss (in-iteration): 	1.211062
#   validation accuracy: 			59.66 %
# Epoch 17 of 20 took 23.315s
#   training loss (in-iteration): 	1.211241
#   validation accuracy: 			59.94 %
# Epoch 18 of 20 took 23.946s
#   training loss (in-iteration): 	1.214815
#   validation accuracy: 			59.91 %
# Epoch 19 of 20 took 24.020s
#   training loss (in-iteration): 	1.207766
#   validation accuracy: 			59.47 %
# Epoch 20 of 20 took 23.973s
#   training loss (in-iteration): 	1.209029
#   validation accuracy: 			59.02 %

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in test_batch_gen:
    X_batch, y_batch = X_batch.to(device), y_batch.to(device)
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
    y_pred = logits.max(1)[1].cpu().data.numpy()
    y_batch = y_batch.cpu().numpy()
    test_batch_acc.append(np.mean(y_batch == y_pred))

test_accuracy = np.mean(test_batch_acc)

print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		65.35 %
# Achievement unlocked: 70lvl Warlock!

# %% [markdown]
# (please read it at least diagonally)
#
# * The ultimate quest is to create a network that has as high __accuracy__ as you can push it.
# * There is a __mini-report__ at the end that you will have to fill in. We recommend reading it first and filling it while you iterate.
#
# ## Grading
# * starting at zero points
# * +20% for describing your iteration path in a report below.
# * +20% for building a network that gets above 20% accuracy
# * +10% for beating each of these milestones on __TEST__ dataset:
#     * 50% (50% points)
#     * 60% (60% points)
#     * 65% (70% points)
#     * 70% (80% points)
#     * 75% (90% points)
#     * 80% (full points)
#
# ## Restrictions
# * Please do NOT use pre-trained networks for this assignment until you reach 80%.
#  * In other words, base milestones must be beaten without pre-trained nets (and such net must be present in the e-mail). After that, you can use whatever you want.
# * you __can__ use validation data for training, but you __can't'__ do anything with test data apart from running the evaluation procedure.
#
# ## Tips on what can be done:
#
#
#  * __Network size__
#    * MOAR neurons,
#    * MOAR layers, ([torch.nn docs](http://pytorch.org/docs/master/nn.html))
#
#    * Nonlinearities in the hidden layers
#      * tanh, relu, leaky relu, etc
#    * Larger networks may take more epochs to train, so don't discard your net just because it could didn't beat the baseline in 5 epochs.
#
#    * Ph'nglui mglw'nafh Cthulhu R'lyeh wgah'nagl fhtagn!
#
#
# ### The main rule of prototyping: one change at a time
#    * By now you probably have several ideas on what to change. By all means, try them out! But there's a catch: __never test several new things at once__.
#
#
# ### Optimization
#    * Training for 100 epochs regardless of anything is probably a bad idea.
#    * Some networks converge over 5 epochs, others - over 500.
#    * Way to go: stop when validation score is 10 iterations past maximum
#    * You should certainly use adaptive optimizers
#      * rmsprop, nesterov_momentum, adam, adagrad and so on.
#      * Converge faster and sometimes reach better optima
#      * It might make sense to tweak learning rate/momentum, other learning parameters, batch size and number of epochs
#    * __BatchNormalization__ (nn.BatchNorm2d) for the win!
#      * Sometimes more batch normalization is better.
#    * __Regularize__ to prevent overfitting
#      * Add some L2 weight norm to the loss function, PyTorch will do the rest
#        * Can be done manually or with weight_decay parameter of a optimizer ([for example SGD's doc](https://pytorch.org/docs/stable/optim.html#torch.optim.SGD)).
#      * Dropout (`nn.Dropout`) - to prevent overfitting
#        * Don't overdo it. Check if it actually makes your network better
#
# ### Convolution architectures
#    * This task __can__ be solved by a sequence of convolutions and poolings with batch_norm and ReLU seasoning, but you shouldn't necessarily stop there.
#    * [Inception family](https://hacktilldawn.com/2016/09/25/inception-modules-explained-and-implemented/), [ResNet family](https://towardsdatascience.com/an-overview-of-resnet-and-its-variants-5281e2f56035?gi=9018057983ca), [Densely-connected convolutions (exotic)](https://arxiv.org/abs/1608.06993), [Capsule networks (exotic)](https://arxiv.org/abs/1710.09829)
#    * Please do try a few simple architectures before you go for resnet-152.
#    * Warning! Training convolutional networks can take long without GPU. That's okay.
#      * If you are CPU-only, we still recomment that you try a simple convolutional architecture
#      * a perfect option is if you can set it up to run at nighttime and check it up at the morning.
#      * Make reasonable layer size estimates. A 128-neuron first convolution is likely an overkill.
#      * __To reduce computation__ time by a factor in exchange for some accuracy drop, try using __stride__ parameter. A stride=2 convolution should take roughly 1/4 of the default (stride=1) one.
#
#
# ### Data augmemntation
#    * getting 5x as large dataset for free is a great
#      * Zoom-in+slice = move
#      * Rotate+zoom(to remove black stripes)
#      * Add Noize (gaussian or bernoulli)
#    * Simple way to do that (if you have PIL/Image):
#      * ```from scipy.misc import imrotate,imresize```
#      * and a few slicing
#      * Other cool libraries: cv2, skimake, PIL/Pillow
#    * A more advanced way is to use torchvision transforms:
#     ```
#     transform_train = transforms.Compose([
#         transforms.RandomCrop(32, padding=4),
#         transforms.RandomHorizontalFlip(),
#         transforms.ToTensor(),
#         transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
#     ])
#     trainset = torchvision.datasets.CIFAR10(root=path_to_cifar_like_in_seminar, train=True, download=True, transform=transform_train)
#     trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)
#
#     ```
#    * Or use this tool from Keras (requires theano/tensorflow): [tutorial](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), [docs](https://keras.io/preprocessing/image/)
#    * Stay realistic. There's usually no point in flipping dogs upside down as that is not the way you usually see them.
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```

# %% [markdown]
# # Homework 2.2: The Quest For A Better Network
#
# In this assignment you will build a monster network to solve CIFAR10 image classification.
#
# This notebook is intended as a sequel to seminar 3, please give it a try if you haven't done so yet.

# %% [markdown]
# # Step 1 After 60%
# Regard previous nn as baseline, it reaches 60%, so expand it, add one more conv layer

# %%
model = nn.Sequential(
    nn.Conv2d(3, 32, kernel_size=3, padding=1),
    nn.BatchNorm2d(32),
    nn.ReLU(),
    nn.Conv2d(32, 32, kernel_size=3, padding=1),
    nn.BatchNorm2d(32),
    nn.ReLU(),
    nn.MaxPool2d(2),  
    
    Flatten(),
    nn.Linear(32 * 16 * 16, 10)  
).to(device)

# %%
import time
num_epochs = 50 # total amount of full passes over training data

opt = torch.optim.Adam(model.parameters())

train_loss = []
val_accuracy = []

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in train_batch_gen:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.cpu().data.numpy())

    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in val_batch_gen:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
        y_pred = logits.max(1)[1].cpu().data.numpy()
        y_batch = y_batch.cpu().numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))


    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 50 took 25.565s
#   training loss (in-iteration): 	1.614316
#   validation accuracy: 			43.95 %
# Epoch 2 of 50 took 25.708s
#   training loss (in-iteration): 	1.436398
#   validation accuracy: 			47.23 %
# Epoch 3 of 50 took 25.336s
#   training loss (in-iteration): 	1.354034
#   validation accuracy: 			52.25 %
# Epoch 4 of 50 took 24.979s
#   training loss (in-iteration): 	1.285284
#   validation accuracy: 			53.75 %
# Epoch 5 of 50 took 25.545s
#   training loss (in-iteration): 	1.225870
#   validation accuracy: 			54.78 %
# Epoch 6 of 50 took 25.679s
#   training loss (in-iteration): 	1.216670
#   validation accuracy: 			57.06 %
# Epoch 7 of 50 took 25.578s
#   training loss (in-iteration): 	1.179641
#   validation accuracy: 			57.69 %
# Epoch 8 of 50 took 25.508s
#   training loss (in-iteration): 	1.155070
#   validation accuracy: 			58.66 %
# Epoch 9 of 50 took 24.962s
#   training loss (in-iteration): 	1.146948
#   validation accuracy: 			58.89 %
# Epoch 10 of 50 took 25.560s
#   training loss (in-iteration): 	1.128157
#   validation accuracy: 			59.64 %
# Epoch 11 of 50 took 25.558s
#   training loss (in-iteration): 	1.109905
#   validation accuracy: 			59.75 %
# Epoch 12 of 50 took 25.494s
#   training loss (in-iteration): 	1.110436
#   validation accuracy: 			59.23 %
# Epoch 13 of 50 took 25.053s
#   training loss (in-iteration): 	1.087960
#   validation accuracy: 			60.25 %
# Epoch 14 of 50 took 24.511s
#   training loss (in-iteration): 	1.088544
#   validation accuracy: 			61.72 %
# Epoch 15 of 50 took 25.422s
#   training loss (in-iteration): 	1.087900
#   validation accuracy: 			61.66 %
# Epoch 16 of 50 took 25.385s
#   training loss (in-iteration): 	1.065587
#   validation accuracy: 			61.39 %
# Epoch 17 of 50 took 25.224s
#   training loss (in-iteration): 	1.070793
#   validation accuracy: 			61.83 %
# Epoch 18 of 50 took 25.164s
#   training loss (in-iteration): 	1.056446
#   validation accuracy: 			61.62 %
# Epoch 19 of 50 took 24.614s
#   training loss (in-iteration): 	1.047802
#   validation accuracy: 			61.25 %
# Epoch 20 of 50 took 25.311s
#   training loss (in-iteration): 	1.049872
#   validation accuracy: 			61.80 %
# Epoch 21 of 50 took 25.289s
#   training loss (in-iteration): 	1.048521
#   validation accuracy: 			61.41 %
# Epoch 22 of 50 took 25.220s
#   training loss (in-iteration): 	1.037480
#   validation accuracy: 			61.67 %
# Epoch 23 of 50 took 25.418s
#   training loss (in-iteration): 	1.044444
#   validation accuracy: 			62.55 %
# Epoch 24 of 50 took 25.123s
#   training loss (in-iteration): 	1.036287
#   validation accuracy: 			62.30 %
# Epoch 25 of 50 took 25.471s
#   training loss (in-iteration): 	1.020869
#   validation accuracy: 			62.59 %
# Epoch 26 of 50 took 25.152s
#   training loss (in-iteration): 	1.020772
#   validation accuracy: 			63.03 %
# Epoch 27 of 50 took 24.910s
#   training loss (in-iteration): 	1.017466
#   validation accuracy: 			62.98 %
# Epoch 28 of 50 took 24.839s
#   training loss (in-iteration): 	1.022233
#   validation accuracy: 			63.41 %
# Epoch 29 of 50 took 23.926s
#   training loss (in-iteration): 	1.006991
#   validation accuracy: 			64.00 %
# Epoch 30 of 50 took 24.586s
#   training loss (in-iteration): 	0.999032
#   validation accuracy: 			63.91 %
# Epoch 31 of 50 took 24.763s
#   training loss (in-iteration): 	1.010946
#   validation accuracy: 			64.14 %
# Epoch 32 of 50 took 24.824s
#   training loss (in-iteration): 	1.007568
#   validation accuracy: 			64.31 %
# Epoch 33 of 50 took 24.187s
#   training loss (in-iteration): 	1.008059
#   validation accuracy: 			64.02 %
# Epoch 34 of 50 took 24.584s
#   training loss (in-iteration): 	1.005864
#   validation accuracy: 			63.42 %
# Epoch 35 of 50 took 24.622s
#   training loss (in-iteration): 	0.994083
#   validation accuracy: 			64.73 %
# Epoch 36 of 50 took 24.653s
#   training loss (in-iteration): 	0.992197
#   validation accuracy: 			63.22 %
# Epoch 37 of 50 took 24.487s
#   training loss (in-iteration): 	0.997082
#   validation accuracy: 			64.73 %
# Epoch 38 of 50 took 24.082s
#   training loss (in-iteration): 	0.991734
#   validation accuracy: 			63.88 %
# Epoch 39 of 50 took 24.460s
#   training loss (in-iteration): 	0.993691
#   validation accuracy: 			64.59 %
# Epoch 40 of 50 took 24.748s
#   training loss (in-iteration): 	0.984390
#   validation accuracy: 			64.88 %
# Epoch 41 of 50 took 24.695s
#   training loss (in-iteration): 	0.992565
#   validation accuracy: 			64.66 %
# Epoch 42 of 50 took 24.143s
#   training loss (in-iteration): 	0.988437
#   validation accuracy: 			65.11 %
# Epoch 43 of 50 took 25.205s
#   training loss (in-iteration): 	0.979218
#   validation accuracy: 			64.91 %
# Epoch 44 of 50 took 25.030s
#   training loss (in-iteration): 	0.978431
#   validation accuracy: 			65.52 %
# Epoch 45 of 50 took 25.004s
#   training loss (in-iteration): 	0.971564
#   validation accuracy: 			65.34 %
# Epoch 46 of 50 took 24.515s
#   training loss (in-iteration): 	0.983276
#   validation accuracy: 			65.25 %
# Epoch 47 of 50 took 23.881s
#   training loss (in-iteration): 	0.975928
#   validation accuracy: 			65.19 %
# Epoch 48 of 50 took 24.597s
#   training loss (in-iteration): 	0.980216
#   validation accuracy: 			65.45 %
# Epoch 49 of 50 took 24.359s
#   training loss (in-iteration): 	0.971494
#   validation accuracy: 			65.41 %
# Epoch 50 of 50 took 24.658s
#   training loss (in-iteration): 	0.973934
#   validation accuracy: 			64.72 %

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in test_batch_gen:
    X_batch, y_batch = X_batch.to(device), y_batch.to(device)
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
    y_pred = logits.max(1)[1].cpu().data.numpy()
    y_batch = y_batch.cpu().numpy()
    test_batch_acc.append(np.mean(y_batch == y_pred))

test_accuracy = np.mean(test_batch_acc)

print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		71.77 %
# Achievement unlocked: 80lvl Warlock!

# %% [markdown]
# # Step 2 After 70%
#
# It reaches 70%, double the size of nn, and due to the increasing size of nn, add more neurons

# %%
model = nn.Sequential(
    nn.Conv2d(3, 32, kernel_size=3, padding=1),
    nn.BatchNorm2d(32),
    nn.ReLU(),
    nn.Conv2d(32, 32, kernel_size=3, padding=1),
    nn.BatchNorm2d(32),
    nn.ReLU(),
    nn.MaxPool2d(2),


    nn.Conv2d(32, 64, kernel_size=3, padding=1),
    nn.BatchNorm2d(64),
    nn.ReLU(),
    nn.Conv2d(64, 64, kernel_size=3, padding=1),
    nn.BatchNorm2d(64),
    nn.ReLU(),
    nn.MaxPool2d(2),


    Flatten(),
    nn.Linear(64 * 8 * 8, 128),
    nn.BatchNorm1d(128),
    nn.ReLU(),
    nn.Dropout(0.1),
    nn.Linear(128, 10)
).to(device)

# %%
import time
num_epochs = 50 # total amount of full passes over training data

opt = torch.optim.Adam(model.parameters())

train_loss = []
val_accuracy = []

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in train_batch_gen:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.cpu().data.numpy())

    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in val_batch_gen:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
        y_pred = logits.max(1)[1].cpu().data.numpy()
        y_batch = y_batch.cpu().numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))


    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 50 took 27.605s
#   training loss (in-iteration): 	1.367383
#   validation accuracy: 			51.41 %
# Epoch 2 of 50 took 26.809s
#   training loss (in-iteration): 	1.154619
#   validation accuracy: 			58.67 %
# Epoch 3 of 50 took 27.381s
#   training loss (in-iteration): 	1.040688
#   validation accuracy: 			61.62 %
# Epoch 4 of 50 took 27.699s
#   training loss (in-iteration): 	0.981797
#   validation accuracy: 			65.59 %
# Epoch 5 of 50 took 27.796s
#   training loss (in-iteration): 	0.940347
#   validation accuracy: 			68.64 %
# Epoch 6 of 50 took 28.153s
#   training loss (in-iteration): 	0.894114
#   validation accuracy: 			69.12 %
# Epoch 7 of 50 took 27.915s
#   training loss (in-iteration): 	0.858189
#   validation accuracy: 			70.36 %
# Epoch 8 of 50 took 28.086s
#   training loss (in-iteration): 	0.837930
#   validation accuracy: 			72.48 %
# Epoch 9 of 50 took 29.307s
#   training loss (in-iteration): 	0.821610
#   validation accuracy: 			73.27 %
# Epoch 10 of 50 took 29.251s
#   training loss (in-iteration): 	0.794033
#   validation accuracy: 			74.00 %
# Epoch 11 of 50 took 28.276s
#   training loss (in-iteration): 	0.778767
#   validation accuracy: 			73.91 %
# Epoch 12 of 50 took 28.704s
#   training loss (in-iteration): 	0.763193
#   validation accuracy: 			73.94 %
# Epoch 13 of 50 took 27.651s
#   training loss (in-iteration): 	0.746287
#   validation accuracy: 			74.41 %
# Epoch 14 of 50 took 27.671s
#   training loss (in-iteration): 	0.729156
#   validation accuracy: 			75.09 %
# Epoch 15 of 50 took 27.679s
#   training loss (in-iteration): 	0.717369
#   validation accuracy: 			75.19 %
# Epoch 16 of 50 took 27.684s
#   training loss (in-iteration): 	0.705226
#   validation accuracy: 			75.64 %
# Epoch 17 of 50 took 27.965s
#   training loss (in-iteration): 	0.693589
#   validation accuracy: 			75.95 %
# Epoch 18 of 50 took 28.982s
#   training loss (in-iteration): 	0.692162
#   validation accuracy: 			76.30 %
# Epoch 19 of 50 took 28.069s
#   training loss (in-iteration): 	0.667326
#   validation accuracy: 			76.27 %
# Epoch 20 of 50 took 28.466s
#   training loss (in-iteration): 	0.674358
#   validation accuracy: 			76.91 %
# Epoch 21 of 50 took 28.716s
#   training loss (in-iteration): 	0.669975
#   validation accuracy: 			76.94 %
# Epoch 22 of 50 took 28.826s
#   training loss (in-iteration): 	0.657083
#   validation accuracy: 			77.14 %
# Epoch 23 of 50 took 29.191s
#   training loss (in-iteration): 	0.654160
#   validation accuracy: 			78.14 %
# Epoch 24 of 50 took 28.752s
#   training loss (in-iteration): 	0.640678
#   validation accuracy: 			77.62 %
# Epoch 25 of 50 took 28.951s
#   training loss (in-iteration): 	0.640851
#   validation accuracy: 			78.23 %
# Epoch 26 of 50 took 29.707s
#   training loss (in-iteration): 	0.625336
#   validation accuracy: 			77.97 %
# Epoch 27 of 50 took 29.179s
#   training loss (in-iteration): 	0.624569
#   validation accuracy: 			78.20 %
# Epoch 28 of 50 took 29.417s
#   training loss (in-iteration): 	0.621006
#   validation accuracy: 			76.95 %
# Epoch 29 of 50 took 28.930s
#   training loss (in-iteration): 	0.618067
#   validation accuracy: 			78.12 %
# Epoch 30 of 50 took 28.363s
#   training loss (in-iteration): 	0.612254
#   validation accuracy: 			78.44 %
# Epoch 31 of 50 took 27.328s
#   training loss (in-iteration): 	0.602271
#   validation accuracy: 			78.00 %
# Epoch 32 of 50 took 28.216s
#   training loss (in-iteration): 	0.600914
#   validation accuracy: 			79.16 %
# Epoch 33 of 50 took 28.502s
#   training loss (in-iteration): 	0.598923
#   validation accuracy: 			78.23 %
# Epoch 34 of 50 took 28.261s
#   training loss (in-iteration): 	0.594962
#   validation accuracy: 			78.77 %
# Epoch 35 of 50 took 28.220s
#   training loss (in-iteration): 	0.598173
#   validation accuracy: 			79.20 %
# Epoch 36 of 50 took 28.049s
#   training loss (in-iteration): 	0.585660
#   validation accuracy: 			80.06 %
# Epoch 37 of 50 took 28.296s
#   training loss (in-iteration): 	0.582005
#   validation accuracy: 			79.47 %
# Epoch 38 of 50 took 28.521s
#   training loss (in-iteration): 	0.576212
#   validation accuracy: 			79.48 %
# Epoch 39 of 50 took 27.753s
#   training loss (in-iteration): 	0.574430
#   validation accuracy: 			78.73 %
# Epoch 40 of 50 took 27.734s
#   training loss (in-iteration): 	0.578973
#   validation accuracy: 			79.16 %
# Epoch 41 of 50 took 28.580s
#   training loss (in-iteration): 	0.579744
#   validation accuracy: 			79.95 %
# Epoch 42 of 50 took 28.000s
#   training loss (in-iteration): 	0.574582
#   validation accuracy: 			80.02 %
# Epoch 43 of 50 took 28.610s
#   training loss (in-iteration): 	0.569865
#   validation accuracy: 			79.41 %
# Epoch 44 of 50 took 28.918s
#   training loss (in-iteration): 	0.567396
#   validation accuracy: 			79.77 %
# Epoch 45 of 50 took 29.123s
#   training loss (in-iteration): 	0.553809
#   validation accuracy: 			79.80 %
# Epoch 46 of 50 took 29.127s
#   training loss (in-iteration): 	0.556019
#   validation accuracy: 			80.38 %
# Epoch 47 of 50 took 29.082s
#   training loss (in-iteration): 	0.560129
#   validation accuracy: 			79.97 %
# Epoch 48 of 50 took 28.574s
#   training loss (in-iteration): 	0.559714
#   validation accuracy: 			79.61 %
# Epoch 49 of 50 took 28.583s
#   training loss (in-iteration): 	0.542031
#   validation accuracy: 			79.39 %
# Epoch 50 of 50 took 27.976s
#   training loss (in-iteration): 	0.549262
#   validation accuracy: 			80.12 %

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in test_batch_gen:
    X_batch, y_batch = X_batch.to(device), y_batch.to(device)
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
    y_pred = logits.max(1)[1].cpu().data.numpy()
    y_batch = y_batch.cpu().numpy()
    test_batch_acc.append(np.mean(y_batch == y_pred))

test_accuracy = np.mean(test_batch_acc)

print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		84.47 %
# Achievement unlocked: 110lvl Warlock!

# %% [markdown]
# # Step 3 After 80%
#
# It reaches 80%, triple the size of nn, increase neurons

# %%
model = nn.Sequential(
    nn.Conv2d(3, 32, kernel_size=3, padding=1),
    nn.BatchNorm2d(32),
    nn.ReLU(),
    nn.Conv2d(32, 32, kernel_size=3, padding=1),
    nn.BatchNorm2d(32),
    nn.ReLU(),
    nn.MaxPool2d(2),
    
    nn.Conv2d(32, 64, kernel_size=3, padding=1),
    nn.BatchNorm2d(64),
    nn.ReLU(),
    nn.Conv2d(64, 64, kernel_size=3, padding=1),
    nn.BatchNorm2d(64),
    nn.ReLU(),
    nn.MaxPool2d(2),

    nn.Conv2d(64, 128, kernel_size=3, padding=1),
    nn.BatchNorm2d(128),
    nn.ReLU(),
    nn.Conv2d(128, 128, kernel_size=3, padding=1),
    nn.BatchNorm2d(128),
    nn.ReLU(),
    nn.MaxPool2d(2),

    Flatten(),
    nn.Linear(128 * 4 * 4, 256), 
    nn.BatchNorm1d(256),
    nn.ReLU(),
    nn.Dropout(0.1),
    nn.Linear(256, 10)
).to(device)

# %%
import time
num_epochs = 50 # total amount of full passes over training data

opt = torch.optim.Adam(model.parameters())

train_loss = []
val_accuracy = []

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in train_batch_gen:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.cpu().data.numpy())

    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in val_batch_gen:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
        y_pred = logits.max(1)[1].cpu().data.numpy()
        y_batch = y_batch.cpu().numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))


    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 50 took 28.636s
#   training loss (in-iteration): 	1.340454
#   validation accuracy: 			53.72 %
# Epoch 2 of 50 took 28.867s
#   training loss (in-iteration): 	1.112762
#   validation accuracy: 			60.70 %
# Epoch 3 of 50 took 28.919s
#   training loss (in-iteration): 	0.970335
#   validation accuracy: 			66.36 %
# Epoch 4 of 50 took 28.647s
#   training loss (in-iteration): 	0.895642
#   validation accuracy: 			68.91 %
# Epoch 5 of 50 took 29.139s
#   training loss (in-iteration): 	0.836615
#   validation accuracy: 			72.52 %
# Epoch 6 of 50 took 29.988s
#   training loss (in-iteration): 	0.783782
#   validation accuracy: 			72.42 %
# Epoch 7 of 50 took 29.959s
#   training loss (in-iteration): 	0.759442
#   validation accuracy: 			74.17 %
# Epoch 8 of 50 took 29.373s
#   training loss (in-iteration): 	0.717413
#   validation accuracy: 			75.31 %
# Epoch 9 of 50 took 29.513s
#   training loss (in-iteration): 	0.683240
#   validation accuracy: 			75.55 %
# Epoch 10 of 50 took 28.599s
#   training loss (in-iteration): 	0.666098
#   validation accuracy: 			76.48 %
# Epoch 11 of 50 took 28.742s
#   training loss (in-iteration): 	0.642522
#   validation accuracy: 			76.81 %
# Epoch 12 of 50 took 28.179s
#   training loss (in-iteration): 	0.627671
#   validation accuracy: 			77.92 %
# Epoch 13 of 50 took 28.245s
#   training loss (in-iteration): 	0.605712
#   validation accuracy: 			78.34 %
# Epoch 14 of 50 took 28.489s
#   training loss (in-iteration): 	0.587027
#   validation accuracy: 			78.84 %
# Epoch 15 of 50 took 28.183s
#   training loss (in-iteration): 	0.577187
#   validation accuracy: 			79.66 %
# Epoch 16 of 50 took 27.456s
#   training loss (in-iteration): 	0.562920
#   validation accuracy: 			80.38 %
# Epoch 17 of 50 took 28.050s
#   training loss (in-iteration): 	0.549138
#   validation accuracy: 			80.41 %
# Epoch 18 of 50 took 28.267s
#   training loss (in-iteration): 	0.548397
#   validation accuracy: 			80.34 %
# Epoch 19 of 50 took 28.075s
#   training loss (in-iteration): 	0.529212
#   validation accuracy: 			80.05 %
# Epoch 20 of 50 took 28.285s
#   training loss (in-iteration): 	0.517705
#   validation accuracy: 			81.92 %
# Epoch 21 of 50 took 28.439s
#   training loss (in-iteration): 	0.500170
#   validation accuracy: 			81.56 %
# Epoch 22 of 50 took 28.722s
#   training loss (in-iteration): 	0.506124
#   validation accuracy: 			81.19 %
# Epoch 23 of 50 took 28.298s
#   training loss (in-iteration): 	0.494211
#   validation accuracy: 			81.67 %
# Epoch 24 of 50 took 28.173s
#   training loss (in-iteration): 	0.490225
#   validation accuracy: 			81.05 %
# Epoch 25 of 50 took 27.704s
#   training loss (in-iteration): 	0.475285
#   validation accuracy: 			82.25 %
# Epoch 26 of 50 took 28.172s
#   training loss (in-iteration): 	0.467689
#   validation accuracy: 			82.73 %
# Epoch 27 of 50 took 27.753s
#   training loss (in-iteration): 	0.464974
#   validation accuracy: 			82.11 %
# Epoch 28 of 50 took 27.687s
#   training loss (in-iteration): 	0.451291
#   validation accuracy: 			82.62 %
# Epoch 29 of 50 took 27.669s
#   training loss (in-iteration): 	0.449528
#   validation accuracy: 			82.02 %
# Epoch 30 of 50 took 27.797s
#   training loss (in-iteration): 	0.441654
#   validation accuracy: 			82.81 %
# Epoch 31 of 50 took 27.690s
#   training loss (in-iteration): 	0.430177
#   validation accuracy: 			82.02 %
# Epoch 32 of 50 took 27.787s
#   training loss (in-iteration): 	0.435935
#   validation accuracy: 			82.56 %
# Epoch 33 of 50 took 27.003s
#   training loss (in-iteration): 	0.430282
#   validation accuracy: 			83.19 %
# Epoch 34 of 50 took 27.599s
#   training loss (in-iteration): 	0.432108
#   validation accuracy: 			83.30 %
# Epoch 35 of 50 took 27.797s
#   training loss (in-iteration): 	0.418388
#   validation accuracy: 			83.11 %
# Epoch 36 of 50 took 27.370s
#   training loss (in-iteration): 	0.408107
#   validation accuracy: 			83.94 %
# Epoch 37 of 50 took 27.670s
#   training loss (in-iteration): 	0.407179
#   validation accuracy: 			84.02 %
# Epoch 38 of 50 took 27.490s
#   training loss (in-iteration): 	0.404811
#   validation accuracy: 			83.38 %
# Epoch 39 of 50 took 27.673s
#   training loss (in-iteration): 	0.405578
#   validation accuracy: 			83.45 %
# Epoch 40 of 50 took 27.749s
#   training loss (in-iteration): 	0.391298
#   validation accuracy: 			83.66 %
# Epoch 41 of 50 took 27.410s
#   training loss (in-iteration): 	0.392629
#   validation accuracy: 			83.22 %
# Epoch 42 of 50 took 27.571s
#   training loss (in-iteration): 	0.394859
#   validation accuracy: 			83.91 %
# Epoch 43 of 50 took 27.705s
#   training loss (in-iteration): 	0.389848
#   validation accuracy: 			83.83 %
# Epoch 44 of 50 took 27.721s
#   training loss (in-iteration): 	0.392575
#   validation accuracy: 			84.36 %
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x795aa3bedbd0>
# Exception ignored in: Traceback (most recent call last):
# <function _MultiProcessingDataLoaderIter.__del__ at 0x795aa3bedbd0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
# self._shutdown_workers()
# if w.is_alive():  File "/opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#
#       File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# if w.is_alive():
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionError
# AssertionError: can only test a child process
# : can only test a child process
# Epoch 45 of 50 took 29.015s
#   training loss (in-iteration): 	0.377594
#   validation accuracy: 			83.81 %
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x795aa3bedbd0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x795aa3bedbd0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Epoch 46 of 50 took 29.764s
#   training loss (in-iteration): 	0.377276
#   validation accuracy: 			84.44 %
# Epoch 47 of 50 took 28.650s
#   training loss (in-iteration): 	0.373089
#   validation accuracy: 			83.94 %
# Epoch 48 of 50 took 28.526s
#   training loss (in-iteration): 	0.362153
#   validation accuracy: 			84.30 %
# Epoch 49 of 50 took 28.503s
#   training loss (in-iteration): 	0.361350
#   validation accuracy: 			84.14 %
# Epoch 50 of 50 took 27.153s
#   training loss (in-iteration): 	0.366154
#   validation accuracy: 			84.25 %

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in test_batch_gen:
    X_batch, y_batch = X_batch.to(device), y_batch.to(device)
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32).to(device))
    y_pred = logits.max(1)[1].cpu().data.numpy()
    y_batch = y_batch.cpu().numpy()
    test_batch_acc.append(np.mean(y_batch == y_pred))

test_accuracy = np.mean(test_batch_acc)

print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		87.74 %
# Achievement unlocked: 110lvl Warlock!
